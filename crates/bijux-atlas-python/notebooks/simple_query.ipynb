# %% [markdown]
# # Atlas Python Client Notebook\nThis notebook demonstrates a simple query flow against Atlas.

# %%
from bijux_atlas import AtlasClient, ClientConfig, QueryRequest\nclient = AtlasClient(ClientConfig(base_url='http://localhost:8080'))\npage = client.query(QueryRequest(dataset='genes', limit=3))\npage.items
